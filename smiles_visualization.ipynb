# %%
import pandas as pd
from sklearn.manifold import TSNE
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from rdkit import DataStructs
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
bgc = pd.read_csv('merge_data/bgc_data_cleaned.csv')
bgc
# Out:
#                          accession  \
# 0                       BGC0001464
# 1                       BGC0000892
# 2                       BGC0002804
# 3                       BGC0001897
# 4                       BGC0001994
# ...                            ...
# 2242         streptoseomycin.fasta
# 2243              Thanamycin.fasta
# 2244  tiancimycin_BGC0001378.fasta
# 2245     titanium_padanamide.fasta
# 2246         WS9326A_cluster.fasta
#
#                                                  SMILES source
# 0                                Brc1[nH]c(Br)c(Br)c1Br  mibig
# 1                      C#CC#CC#CC#CC=CC=CC(O)CCCCC(=O)O  mibig
# 2                          C#CC#CC#CC#CC=CCCCCCCCC(=O)O  mibig
# 3                    C#CC#CC=C=CC1OC1C(O)C=CC1CCC(=O)O1  mibig
# 4                                     C#CC(O)C(N)C(=O)O  mibig
# ...                                                 ...    ...
# 2242  COC1CC2C=CC3CC4CC(O)C3C2(O4)C(C)=CC2COC(=O)CCC...  prism
# 2243  CC=C1NC(=O)C(C(C)O)NC(=O)C(Cc2cccc3[nH]ccc23)N...  prism
# 2244  Cc1cc2c(c3c1C(=O)c1ccc(C(=O)O)c(O)c1C3=O)NC1C#...  prism
# 2245  COCC(=O)NC(C(=O)N1NCCCC1C(=O)NC(Cc1ccccc1)C(O)...  prism
# 2246  CCCC=Cc1ccccc1C=CC(=O)NC1C(=O)N(C)C(=Cc2ccc(O)...  prism
#
# [2247 rows x 3 columns]

# %%
fp_generator = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

bgc['fingerprint'] = bgc['SMILES'].apply(lambda x: fp_generator.GetFingerprint(Chem.MolFromSmiles(x)))
# Out:
# [14:00:29] WARNING: not removing hydrogen atom without neighbors
# [14:00:29] WARNING: not removing hydrogen atom without neighbors
# [14:00:29] WARNING: not removing hydrogen atom without neighbors
# [14:00:29] WARNING: not removing hydrogen atom without neighbors

# %%
def fp_to_array(fp):
    arr = np.zeros((1,))
    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr

fp_array = np.array([fp_to_array(fp) for fp in bgc['fingerprint']])

# %%
tsne = TSNE(n_components=2, random_state=333)
tsne_results = tsne.fit_transform(fp_array)

# %%
tsne_df = pd.DataFrame({
    'tsne_1': tsne_results[:,0],
    'tsne_2': tsne_results[:,1],
    'source': bgc['source']
})

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=tsne_df, x='tsne_1', y='tsne_2', hue='source', alpha=0.7)
plt.title('t-SNE Visualization of Morgan Fingerprints')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
